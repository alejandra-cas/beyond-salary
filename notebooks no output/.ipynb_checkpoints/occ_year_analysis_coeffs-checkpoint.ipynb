# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# import stargazer
from stargazer.stargazer import Stargazer

# %%
import sys
import os

# Add parent directory to sys.path
parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.append(parent_dir)

# %%
from package_files.benefits_defns import *

# %% [markdown]
# # Read in data

# %%
df = pd.read_csv('../exports/occ_year_coeff_analysis.csv')

# %%
df
# Out:
#               Benefit                                      Occupation  Year  \
# 0      EDU_ASSISTANCE        Architecture and Engineering Occupations  2019
# 1                 WLB        Architecture and Engineering Occupations  2019
# 2          PAID_LEAVE        Architecture and Engineering Occupations  2019
# 3    HEALTH_WELLBEING        Architecture and Engineering Occupations  2019
# 4      PARENTAL_LEAVE        Architecture and Engineering Occupations  2019
# ..                ...                                             ...   ...
# 604        PAID_LEAVE  Transportation and Material Moving Occupations  2023
# 605  HEALTH_WELLBEING  Transportation and Material Moving Occupations  2023
# 606    PARENTAL_LEAVE  Transportation and Material Moving Occupations  2023
# 607           CULTURE  Transportation and Material Moving Occupations  2023
# 608          wfh_wham  Transportation and Material Moving Occupations  2023
#
#      AI Coefficient     Error  P-Value  \
# 0         -0.378773  0.202133    0.061
# 1         -0.155173  0.112814    0.169
# 2         -0.303556  0.125737    0.016
# 3         -0.590114  0.272715    0.030
# 4          0.958254  0.256600    0.000
# ..              ...       ...      ...
# 604       -0.585309  0.243334    0.016
# 605       -0.316241  0.465671    0.497
# 606       -0.826458  0.529267    0.118
# 607        1.039471  0.268258    0.000
# 608        0.597295  0.549521    0.277
#
#                                     SOC_2021_2_NAME  YEAR  AI Demand  \
# 0          Architecture and Engineering Occupations  2019  58.064516
# 1          Architecture and Engineering Occupations  2019  58.064516
# 2          Architecture and Engineering Occupations  2019  58.064516
# 3          Architecture and Engineering Occupations  2019  58.064516
# 4          Architecture and Engineering Occupations  2019  58.064516
# ..                                              ...   ...        ...
# 604  Transportation and Material Moving Occupations  2023   7.281553
# 605  Transportation and Material Moving Occupations  2023   7.281553
# 606  Transportation and Material Moving Occupations  2023   7.281553
# 607  Transportation and Material Moving Occupations  2023   7.281553
# 608  Transportation and Material Moving Occupations  2023   7.281553
#
#      AI Demand % Change  PRIOR YEAR % CHANGE  LOG_SALARY_ai     SALARY_ai  \
# 0            -10.483871                  NaN      11.359202  89522.055556
# 1            -10.483871                  NaN      11.359202  89522.055556
# 2            -10.483871                  NaN      11.359202  89522.055556
# 3            -10.483871                  NaN      11.359202  89522.055556
# 4            -10.483871                  NaN      11.359202  89522.055556
# ..                  ...                  ...            ...           ...
# 604           17.545076           133.333333      10.911690  59932.333333
# 605           17.545076           133.333333      10.911690  59932.333333
# 606           17.545076           133.333333      10.911690  59932.333333
# 607           17.545076           133.333333      10.911690  59932.333333
# 608           17.545076           133.333333      10.911690  59932.333333
#
#      LOG_SALARY_non_ai  SALARY_non_ai  Salary (Log) Premium  SALARY_PREMIUM  \
# 0            10.959258   61962.384615            103.649371      144.478067
# 1            10.959258   61962.384615            103.649371      144.478067
# 2            10.959258   61962.384615            103.649371      144.478067
# 3            10.959258   61962.384615            103.649371      144.478067
# 4            10.959258   61962.384615            103.649371      144.478067
# ..                 ...            ...                   ...             ...
# 604          10.727245   49245.099476            101.719408      121.702127
# 605          10.727245   49245.099476            101.719408      121.702127
# 606          10.727245   49245.099476            101.719408      121.702127
# 607          10.727245   49245.099476            101.719408      121.702127
# 608          10.727245   49245.099476            101.719408      121.702127
#
#      job_count  Prevalence: Tuition Assistance  Prevalence: Paid Leave  \
# 0           31                        9.677419                6.451613
# 1           31                        9.677419                6.451613
# 2           31                        9.677419                6.451613
# 3           31                        9.677419                6.451613
# 4           31                        9.677419                6.451613
# ..         ...                             ...                     ...
# 604        206                        9.708738               46.116505
# 605        206                        9.708738               46.116505
# 606        206                        9.708738               46.116505
# 607        206                        9.708738               46.116505
# 608        206                        9.708738               46.116505
#
#      Prevalence: Health and Wellbeing  Prevalence: Parental Leave  \
# 0                            3.225806                    0.000000
# 1                            3.225806                    0.000000
# 2                            3.225806                    0.000000
# 3                            3.225806                    0.000000
# 4                            3.225806                    0.000000
# ..                                ...                         ...
# 604                          7.281553                    4.854369
# 605                          7.281553                    4.854369
# 606                          7.281553                    4.854369
# 607                          7.281553                    4.854369
# 608                          7.281553                    4.854369
#
#      Prevalence: Workplace Culture  Prevalence: Remote Work
# 0                         0.000000                12.903226
# 1                         0.000000                12.903226
# 2                         0.000000                12.903226
# 3                         0.000000                12.903226
# 4                         0.000000                12.903226
# ..                             ...                      ...
# 604                       8.252427                 0.980392
# 605                       8.252427                 0.980392
# 606                       8.252427                 0.980392
# 607                       8.252427                 0.980392
# 608                       8.252427                 0.980392
#
# [609 rows x 24 columns]

# %%
plt.hist(df_dict['EDU_ASSISTANCE']['AI ROLE %'], bins=20)
# Out:
# (array([ 4., 16.,  8.,  9.,  7.,  5.,  6.,  3.,  5.,  4.,  1.,  3.,  2.,
#          4.,  5.,  1.,  0.,  2.,  1.,  3.]),
#  array([0.00961538, 0.05650304, 0.10339069, 0.15027834, 0.19716599,
#         0.24405364, 0.2909413 , 0.33782895, 0.3847166 , 0.43160425,
#         0.4784919 , 0.52537955, 0.57226721, 0.61915486, 0.66604251,
#         0.71293016, 0.75981781, 0.80670547, 0.85359312, 0.90048077,
#         0.94736842]),
#  <BarContainer object of 20 artists>)

# %%
pd.set_option('display.max_columns', None)

# %%
# show rows in df with nas in ai coefficient
df[df['AI Coefficient'].isna()]
# Out:
#               Benefit                                         Occupation  \
# 73     PARENTAL_LEAVE  Arts, Design, Entertainment, Sports, and Media...
# 134    PARENTAL_LEAVE           Community and Social Service Occupations
# 250    PARENTAL_LEAVE  Healthcare Practitioners and Technical Occupat...
# 290  HEALTH_WELLBEING                                  Legal Occupations
# 447        PAID_LEAVE              Personal Care and Service Occupations
# 449    PARENTAL_LEAVE              Personal Care and Service Occupations
# 466    EDU_ASSISTANCE              Personal Care and Service Occupations
# 575    EDU_ASSISTANCE     Transportation and Material Moving Occupations
# 578  HEALTH_WELLBEING     Transportation and Material Moving Occupations
#
#      Year  AI Coefficient  Error  P-Value  \
# 73   2018             NaN    NaN      NaN
# 134  2021             NaN    NaN      NaN
# 250  2019             NaN    NaN      NaN
# 290  2019             NaN    NaN      NaN
# 447  2019             NaN    NaN      NaN
# 449  2019             NaN    NaN      NaN
# 466  2020             NaN    NaN      NaN
# 575  2021             NaN    NaN      NaN
# 578  2021             NaN    NaN      NaN
#
#                                        SOC_2021_2_NAME  YEAR  AI ROLE %  \
# 73   Arts, Design, Entertainment, Sports, and Media...  2018   0.185185
# 134           Community and Social Service Occupations  2021   0.170732
# 250  Healthcare Practitioners and Technical Occupat...  2019   0.120482
# 290                                  Legal Occupations  2019   0.083333
# 447              Personal Care and Service Occupations  2019   0.115385
# 449              Personal Care and Service Occupations  2019   0.115385
# 466              Personal Care and Service Occupations  2020   0.083333
# 575     Transportation and Material Moving Occupations  2021   0.026549
# 578     Transportation and Material Moving Occupations  2021   0.026549
#
#      AI ROLE % CHANGE  PRIOR YEAR % CHANGE  LOG_SALARY_ai      SALARY_ai  \
# 73                NaN                  NaN      10.986849   66221.800000
# 134          8.130081           105.263158      11.269833   92866.714286
# 250         32.530120                  NaN      11.337880  102556.400000
# 290               inf                  NaN      11.082143   65000.000000
# 447         -7.692308                  NaN      10.369686   33973.333333
# 449         -7.692308                  NaN      10.369686   33973.333333
# 466        -27.777778            -7.692308       9.890028   19760.000000
# 575         19.469027            20.000000      10.870462   64642.666667
# 578         19.469027            20.000000      10.870462   64642.666667
#
#      LOG_SALARY_non_ai  SALARY_non_ai  SALARY_PREMIUM_LOG  SALARY_PREMIUM  \
# 73           10.686384   50553.545455          102.811662      130.993384
# 134          10.797247   52644.294118          104.376913      176.404140
# 250          11.284890   92351.671233          100.469565      111.049858
# 290          10.968769   64360.545455          101.033605      100.993551
# 447          10.384312   33684.086957           99.859158      100.858703
# 449          10.384312   33684.086957           99.859158      100.858703
# 466          10.323897   33291.363636           95.797431       59.354733
# 575          10.659290   46575.627273          101.981109      138.790759
# 578          10.659290   46575.627273          101.981109      138.790759
#
#      job_count  Percent_with_EDU_ASSISTANCE  Percent_with_PAID_LEAVE  \
# 73          27                     0.000000                 0.185185
# 134         41                     0.146341                 0.439024
# 250         83                     0.036145                 0.216867
# 290         12                     0.000000                 0.250000
# 447         26                     0.000000                 0.115385
# 449         26                     0.000000                 0.115385
# 466         24                     0.041667                 0.208333
# 575        226                     0.048673                 0.398230
# 578        226                     0.048673                 0.398230
#
#      Percent_with_HEALTH_WELLBEING  Percent_with_PARENTAL_LEAVE  \
# 73                        0.000000                     0.037037
# 134                       0.048780                     0.024390
# 250                       0.024096                     0.000000
# 290                       0.083333                     0.083333
# 447                       0.000000                     0.000000
# 449                       0.000000                     0.000000
# 466                       0.041667                     0.041667
# 575                       0.066372                     0.022124
# 578                       0.066372                     0.022124
#
#      Percent_with_CULTURE  Percent_with_wfh_wham
# 73               0.037037                    NaN
# 134              0.097561               0.195122
# 250              0.060241               0.024096
# 290              0.083333               0.250000
# 447              0.038462               0.000000
# 449              0.038462               0.000000
# 466              0.000000               0.043478
# 575              0.013274               0.004484
# 578              0.013274               0.004484

# %%
# create dict of benefit dfs
df_dict = {}
for benefit in benefits4:
    benefit_df = df[df['Benefit'] == benefit]
    df_dict[benefit] = benefit_df

# %% [markdown]
# # Run Models

# %% [markdown]
# ## Baseline with Demand (1)

# %%
import statsmodels.api as sm
benefit_models = {}
for benefit in df_dict.keys():
    benefit_df = df_dict[benefit]
    # drop nas in AI Coefficient
    benefit_df = benefit_df.dropna(subset=['AI Coefficient'])
    # Define the dependent and independent variables
    X = benefit_df['AI Demand']
    y = benefit_df['AI Coefficient']

    # Add a constant to the independent variable
    X = sm.add_constant(X)

    # Fit the OLS model
    model = sm.OLS(y, X).fit()
    print(benefit)
    benefit_models[benefit] = []
    benefit_models[benefit].append(model)
    # Print the summary of the regression
    print(model.summary())
# Out:
# EDU_ASSISTANCE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.070
# Model:                            OLS   Adj. R-squared:                  0.059
# Method:                 Least Squares   F-statistic:                     6.366
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):             0.0135
# Time:                        17:04:44   Log-Likelihood:                -285.34
# No. Observations:                  87   AIC:                             574.7
# Df Residuals:                      85   BIC:                             579.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -4.4433      1.167     -3.807      0.000      -6.764      -2.123
# AI Demand      0.0706      0.028      2.523      0.013       0.015       0.126
# ==============================================================================
# Omnibus:                      117.442   Durbin-Watson:                   1.721
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2597.430
# Skew:                          -4.509   Prob(JB):                         0.00
# Kurtosis:                      28.203   Cond. No.                         69.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# PAID_LEAVE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.186
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     19.69
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):           2.68e-05
# Time:                        17:04:44   Log-Likelihood:                -37.129
# No. Observations:                  88   AIC:                             78.26
# Df Residuals:                      86   BIC:                             83.21
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6871      0.066    -10.424      0.000      -0.818      -0.556
# AI Demand      0.0071      0.002      4.437      0.000       0.004       0.010
# ==============================================================================
# Omnibus:                       35.799   Durbin-Watson:                   1.660
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               89.224
# Skew:                          -1.418   Prob(JB):                     4.22e-20
# Kurtosis:                       7.036   Cond. No.                         68.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# HEALTH_WELLBEING
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     2.148
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.146
# Time:                        17:04:44   Log-Likelihood:                -176.76
# No. Observations:                  87   AIC:                             357.5
# Df Residuals:                      85   BIC:                             362.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.6333      0.335     -1.890      0.062      -1.299       0.033
# AI Demand      0.0118      0.008      1.466      0.146      -0.004       0.028
# ==============================================================================
# Omnibus:                      135.274   Durbin-Watson:                   1.836
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4729.884
# Skew:                          -5.460   Prob(JB):                         0.00
# Kurtosis:                      37.432   Cond. No.                         69.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# PARENTAL_LEAVE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.101
# Model:                            OLS   Adj. R-squared:                  0.090
# Method:                 Least Squares   F-statistic:                     9.339
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):            0.00302
# Time:                        17:04:44   Log-Likelihood:                -251.56
# No. Observations:                  85   AIC:                             507.1
# Df Residuals:                      83   BIC:                             512.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.4395      0.854     -4.028      0.000      -5.138      -1.741
# AI Demand      0.0620      0.020      3.056      0.003       0.022       0.102
# ==============================================================================
# Omnibus:                       60.729   Durbin-Watson:                   1.853
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              215.765
# Skew:                          -2.489   Prob(JB):                     1.40e-47
# Kurtosis:                       9.012   Cond. No.                         70.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CULTURE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.4999
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.481
# Time:                        17:04:44   Log-Likelihood:                -198.77
# No. Observations:                  89   AIC:                             401.5
# Df Residuals:                      87   BIC:                             406.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.1543      0.400      0.386      0.700      -0.640       0.949
# AI Demand      0.0068      0.010      0.707      0.481      -0.012       0.026
# ==============================================================================
# Omnibus:                      185.322   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22869.425
# Skew:                          -8.652   Prob(JB):                         0.00
# Kurtosis:                      79.600   Cond. No.                         68.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# wfh_wham
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     2.033
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.158
# Time:                        17:04:44   Log-Likelihood:                -201.86
# No. Observations:                  75   AIC:                             407.7
# Df Residuals:                      73   BIC:                             412.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8731      0.694     -1.258      0.212      -2.257       0.510
# AI Demand      0.0236      0.017      1.426      0.158      -0.009       0.057
# ==============================================================================
# Omnibus:                      103.864   Durbin-Watson:                   2.220
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1658.304
# Skew:                          -4.510   Prob(JB):                         0.00
# Kurtosis:                      24.196   Cond. No.                         69.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## + Prevalence (2)

# %%
import statsmodels.api as sm
for benefit in benefits4:
    benefit_df = df_dict[benefit]
    # drop nas in AI Coefficient
    benefit_df = benefit_df.dropna(subset=['AI Coefficient'])
    # Define the dependent and independent variables
    # X is AI ROLE % and Percent_with_{benefit}
    # benefit_df.rename(columns={f'{benefit}_prevalence}': f'Prevalence: {label}', inplace=True)
    label = benefits_labels_map[benefit]
    X = benefit_df[['AI Demand', f'Prevalence: {label}']]
    y = benefit_df['AI Coefficient']

    # Add a constant to the independent variable
    X = sm.add_constant(X)

    # Fit the OLS model
    model = sm.OLS(y, X).fit()
    print(benefit)
    benefit_models[benefit].append(model)
    # Print the summary of the regression
    print(model.summary())
# Out:
# EDU_ASSISTANCE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.095
# Model:                            OLS   Adj. R-squared:                  0.074
# Method:                 Least Squares   F-statistic:                     4.423
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):             0.0149
# Time:                        17:04:49   Log-Likelihood:                -284.12
# No. Observations:                  87   AIC:                             574.2
# Df Residuals:                      84   BIC:                             581.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             -5.9120      1.499     -3.943      0.000      -8.894      -2.931
# AI Demand                          0.0633      0.028      2.247      0.027       0.007       0.119
# Prevalence: Tuition Assistance     0.2531      0.164      1.542      0.127      -0.073       0.579
# ==============================================================================
# Omnibus:                      112.532   Durbin-Watson:                   1.709
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2200.250
# Skew:                          -4.267   Prob(JB):                         0.00
# Kurtosis:                      26.111   Cond. No.                         91.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# PAID_LEAVE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     10.33
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):           9.64e-05
# Time:                        17:04:49   Log-Likelihood:                -36.627
# No. Observations:                  88   AIC:                             79.25
# Df Residuals:                      85   BIC:                             86.69
# Df Model:                           2
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.5876      0.120     -4.878      0.000      -0.827      -0.348
# AI Demand                  0.0070      0.002      4.409      0.000       0.004       0.010
# Prevalence: Paid Leave    -0.0034      0.003     -0.987      0.326      -0.010       0.003
# ==============================================================================
# Omnibus:                       36.303   Durbin-Watson:                   1.658
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               87.009
# Skew:                          -1.465   Prob(JB):                     1.28e-19
# Kurtosis:                       6.892   Cond. No.                         148.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# HEALTH_WELLBEING
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.084
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.343
# Time:                        17:04:49   Log-Likelihood:                -176.74
# No. Observations:                  87   AIC:                             359.5
# Df Residuals:                      84   BIC:                             366.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                               -0.6741      0.389     -1.735      0.086      -1.447       0.098
# AI Demand                            0.0113      0.008      1.343      0.183      -0.005       0.028
# Prevalence: Health and Wellbeing     0.0122      0.058      0.211      0.833      -0.103       0.127
# ==============================================================================
# Omnibus:                      135.286   Durbin-Watson:                   1.842
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4744.317
# Skew:                          -5.458   Prob(JB):                         0.00
# Kurtosis:                      37.491   Cond. No.                         81.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# PARENTAL_LEAVE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.107
# Model:                            OLS   Adj. R-squared:                  0.085
# Method:                 Least Squares   F-statistic:                     4.888
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):            0.00988
# Time:                        17:04:49   Log-Likelihood:                -251.31
# No. Observations:                  85   AIC:                             508.6
# Df Residuals:                      82   BIC:                             515.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         -3.6085      0.890     -4.056      0.000      -5.379      -1.839
# AI Demand                      0.0557      0.022      2.501      0.014       0.011       0.100
# Prevalence: Parental Leave     0.0930      0.132      0.702      0.485      -0.170       0.356
# ==============================================================================
# Omnibus:                       59.856   Durbin-Watson:                   1.835
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              208.091
# Skew:                          -2.457   Prob(JB):                     6.51e-46
# Kurtosis:                       8.882   Cond. No.                         73.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# CULTURE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.5740
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.565
# Time:                        17:04:49   Log-Likelihood:                -198.43
# No. Observations:                  89   AIC:                             402.9
# Df Residuals:                      86   BIC:                             410.3
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                             0.0462      0.422      0.110      0.913      -0.793       0.886
# AI Demand                         0.0025      0.011      0.226      0.821      -0.020       0.025
# Prevalence: Workplace Culture     0.0289      0.036      0.806      0.422      -0.042       0.100
# ==============================================================================
# Omnibus:                      184.254   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22246.682
# Skew:                          -8.564   Prob(JB):                         0.00
# Kurtosis:                      78.537   Cond. No.                         73.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# wfh_wham
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.011
# Method:                 Least Squares   F-statistic:                     1.396
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.254
# Time:                        17:04:49   Log-Likelihood:                -201.46
# No. Observations:                  75   AIC:                             408.9
# Df Residuals:                      72   BIC:                             415.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                      -0.9995      0.710     -1.407      0.164      -2.415       0.416
# AI Demand                   0.0085      0.024      0.356      0.723      -0.039       0.056
# Prevalence: Remote Work     0.0364      0.042      0.875      0.384      -0.046       0.119
# ==============================================================================
# Omnibus:                      102.131   Durbin-Watson:                   2.219
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1564.118
# Skew:                          -4.412   Prob(JB):                         0.00
# Kurtosis:                      23.558   Cond. No.                         79.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
from IPython.core.display import HTML

# %% [markdown]
# ## + Salary (3)

# %%
import statsmodels.api as sm
for benefit in benefits4:
    benefit_df = df_dict[benefit]
    # drop nas in AI Coefficient
    benefit_df = benefit_df.dropna(subset=['AI Coefficient'])
    # Define the dependent and independent variables
    # X is AI ROLE % and Percent_with_{benefit}
    label = benefits_labels_map[benefit]
    # benefit_df.rename(columns={f'{benefit}_prevalence}': f'Prevalence: {label}', inplace=True)
    X = benefit_df[['AI Demand', f'Prevalence: {label}', 'Salary (Log) Premium']]
    y = benefit_df['AI Coefficient']

    # Add a constant to the independent variable
    X = sm.add_constant(X)

    # Fit the OLS model
    model = sm.OLS(y, X).fit()
    print(benefit)
    benefit_models[benefit].append(model)
    # Print the summary of the regression
    print(model.summary())
# Out:
# EDU_ASSISTANCE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.113
# Model:                            OLS   Adj. R-squared:                  0.081
# Method:                 Least Squares   F-statistic:                     3.539
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):             0.0181
# Time:                        17:04:52   Log-Likelihood:                -283.24
# No. Observations:                  87   AIC:                             574.5
# Df Residuals:                      83   BIC:                             584.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# const                             27.6477     25.802      1.072      0.287     -23.672      78.967
# AI Demand                          0.0691      0.028      2.433      0.017       0.013       0.126
# Prevalence: Tuition Assistance     0.2295      0.164      1.395      0.167      -0.098       0.557
# Salary (Log) Premium              -0.3261      0.250     -1.303      0.196      -0.824       0.172
# ==============================================================================
# Omnibus:                      118.901   Durbin-Watson:                   1.649
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2837.743
# Skew:                          -4.556   Prob(JB):                         0.00
# Kurtosis:                      29.454   Cond. No.                     4.08e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.08e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# PAID_LEAVE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.196
# Model:                            OLS   Adj. R-squared:                  0.167
# Method:                 Least Squares   F-statistic:                     6.819
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):           0.000361
# Time:                        17:04:52   Log-Likelihood:                -36.609
# No. Observations:                  88   AIC:                             81.22
# Df Residuals:                      84   BIC:                             91.13
# Df Model:                           3
# Covariance Type:            nonrobust
# ==========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------
# const                     -0.8543      1.449     -0.589      0.557      -3.737       2.028
# AI Demand                  0.0070      0.002      4.298      0.000       0.004       0.010
# Prevalence: Paid Leave    -0.0034      0.003     -0.995      0.322      -0.010       0.003
# Salary (Log) Premium       0.0026      0.014      0.185      0.854      -0.026       0.031
# ==============================================================================
# Omnibus:                       36.548   Durbin-Watson:                   1.668
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               88.145
# Skew:                          -1.472   Prob(JB):                     7.24e-20
# Kurtosis:                       6.920   Cond. No.                     4.07e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.07e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# HEALTH_WELLBEING
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.125
# Model:                            OLS   Adj. R-squared:                  0.093
# Method:                 Least Squares   F-statistic:                     3.957
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):             0.0109
# Time:                        17:04:53   Log-Likelihood:                -172.03
# No. Observations:                  87   AIC:                             352.1
# Df Residuals:                      83   BIC:                             361.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                              -21.9449      6.918     -3.172      0.002     -35.704      -8.186
# AI Demand                            0.0070      0.008      0.859      0.393      -0.009       0.023
# Prevalence: Health and Wellbeing     0.0257      0.055      0.464      0.644      -0.084       0.136
# Salary (Log) Premium                 0.2074      0.067      3.079      0.003       0.073       0.341
# ==============================================================================
# Omnibus:                      116.405   Durbin-Watson:                   1.724
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2792.429
# Skew:                          -4.385   Prob(JB):                         0.00
# Kurtosis:                      29.333   Cond. No.                     3.92e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.92e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# PARENTAL_LEAVE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.222
# Model:                            OLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     7.702
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):           0.000137
# Time:                        17:04:53   Log-Likelihood:                -245.43
# No. Observations:                  85   AIC:                             498.9
# Df Residuals:                      81   BIC:                             508.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                         56.1760     17.265      3.254      0.002      21.824      90.528
# AI Demand                      0.0646      0.021      3.068      0.003       0.023       0.106
# Prevalence: Parental Leave     0.1138      0.124      0.914      0.363      -0.134       0.361
# Salary (Log) Premium          -0.5844      0.169     -3.467      0.001      -0.920      -0.249
# ==============================================================================
# Omnibus:                       55.678   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              182.041
# Skew:                          -2.275   Prob(JB):                     2.95e-40
# Kurtosis:                       8.541   Cond. No.                     3.89e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.89e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# CULTURE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.021
# Method:                 Least Squares   F-statistic:                    0.3848
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.764
# Time:                        17:04:53   Log-Likelihood:                -198.42
# No. Observations:                  89   AIC:                             404.8
# Df Residuals:                      85   BIC:                             414.8
# Df Model:                           3
# Covariance Type:            nonrobust
# =================================================================================================
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# const                            -1.1849      8.840     -0.134      0.894     -18.761      16.392
# AI Demand                         0.0023      0.011      0.199      0.842      -0.020       0.025
# Prevalence: Workplace Culture     0.0291      0.036      0.806      0.422      -0.043       0.101
# Salary (Log) Premium              0.0120      0.086      0.139      0.889      -0.159       0.184
# ==============================================================================
# Omnibus:                      184.155   Durbin-Watson:                   2.064
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            22197.074
# Skew:                          -8.555   Prob(JB):                         0.00
# Kurtosis:                      78.452   Cond. No.                     3.94e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.94e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# wfh_wham
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.043
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.055
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.374
# Time:                        17:04:53   Log-Likelihood:                -201.25
# No. Observations:                  75   AIC:                             410.5
# Df Residuals:                      71   BIC:                             419.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     -12.4735     18.270     -0.683      0.497     -48.903      23.956
# AI Demand                   0.0097      0.024      0.401      0.690      -0.038       0.058
# Prevalence: Remote Work     0.0285      0.044      0.654      0.515      -0.058       0.115
# Salary (Log) Premium        0.1123      0.179      0.629      0.532      -0.244       0.469
# ==============================================================================
# Omnibus:                      101.040   Durbin-Watson:                   2.187
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1518.132
# Skew:                          -4.346   Prob(JB):                         0.00
# Kurtosis:                      23.255   Cond. No.                     4.79e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.79e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
for benefit in benefits4:
    stargazer = Stargazer(benefit_models[benefit])
    display(HTML(stargazer.render_html()))
    # export to latex
    with open(f'../exports/occ_year_coeff_{benefit}.tex', 'w') as f:
        f.write(stargazer.render_latex())
# Out:
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.071<sup>**</sup></td><td>0.063<sup>**</sup></td><td>0.069<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.028)</td><td>(0.028)</td><td>(0.028)</td></tr>
# <tr><td style="text-align:left">Prevalence: Tuition Assistance</td><td></td><td>0.253<sup></sup></td><td>0.229<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.164)</td><td>(0.164)</td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>-0.326<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.250)</td></tr>
# <tr><td style="text-align:left">const</td><td>-4.443<sup>***</sup></td><td>-5.912<sup>***</sup></td><td>27.648<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(1.167)</td><td>(1.499)</td><td>(25.802)</td></tr>
#
# <td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>87</td><td>87</td><td>87</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.070</td><td>0.095</td><td>0.113</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.059</td><td>0.074</td><td>0.081</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>6.504 (df=85)</td><td>6.452 (df=84)</td><td>6.426 (df=83)</td></tr><tr><td style="text-align: left">F Statistic</td><td>6.366<sup>**</sup> (df=1; 85)</td><td>4.423<sup>**</sup> (df=2; 84)</td><td>3.539<sup>**</sup> (df=3; 83)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="3" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.007<sup>***</sup></td><td>0.007<sup>***</sup></td><td>0.007<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.002)</td><td>(0.002)</td><td>(0.002)</td></tr>
# <tr><td style="text-align:left">Prevalence: Paid Leave</td><td></td><td>-0.003<sup></sup></td><td>-0.003<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.003)</td><td>(0.003)</td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>0.003<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">const</td><td>-0.687<sup>***</sup></td><td>-0.588<sup>***</sup></td><td>-0.854<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.066)</td><td>(0.120)</td><td>(1.449)</td></tr>
#
# <td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>88</td><td>88</td><td>88</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.186</td><td>0.196</td><td>0.196</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.177</td><td>0.177</td><td>0.167</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.373 (df=86)</td><td>0.373 (df=85)</td><td>0.375 (df=84)</td></tr><tr><td style="text-align: left">F Statistic</td><td>19.691<sup>***</sup> (df=1; 86)</td><td>10.330<sup>***</sup> (df=2; 85)</td><td>6.819<sup>***</sup> (df=3; 84)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="3" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.012<sup></sup></td><td>0.011<sup></sup></td><td>0.007<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.008)</td><td>(0.008)</td><td>(0.008)</td></tr>
# <tr><td style="text-align:left">Prevalence: Health and Wellbeing</td><td></td><td>0.012<sup></sup></td><td>0.026<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.058)</td><td>(0.055)</td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>0.207<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.067)</td></tr>
# <tr><td style="text-align:left">const</td><td>-0.633<sup>*</sup></td><td>-0.674<sup>*</sup></td><td>-21.945<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.335)</td><td>(0.389)</td><td>(6.918)</td></tr>
#
# <td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>87</td><td>87</td><td>87</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.025</td><td>0.025</td><td>0.125</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.013</td><td>0.002</td><td>0.093</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>1.867 (df=85)</td><td>1.878 (df=84)</td><td>1.790 (df=83)</td></tr><tr><td style="text-align: left">F Statistic</td><td>2.148<sup></sup> (df=1; 85)</td><td>1.084<sup></sup> (df=2; 84)</td><td>3.957<sup>**</sup> (df=3; 83)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="3" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.062<sup>***</sup></td><td>0.056<sup>**</sup></td><td>0.065<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.020)</td><td>(0.022)</td><td>(0.021)</td></tr>
# <tr><td style="text-align:left">Prevalence: Parental Leave</td><td></td><td>0.093<sup></sup></td><td>0.114<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.132)</td><td>(0.124)</td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>-0.584<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.169)</td></tr>
# <tr><td style="text-align:left">const</td><td>-3.439<sup>***</sup></td><td>-3.609<sup>***</sup></td><td>56.176<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.854)</td><td>(0.890)</td><td>(17.265)</td></tr>
#
# <td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>85</td><td>85</td><td>85</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.101</td><td>0.107</td><td>0.222</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.090</td><td>0.085</td><td>0.193</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>4.723 (df=83)</td><td>4.738 (df=82)</td><td>4.448 (df=81)</td></tr><tr><td style="text-align: left">F Statistic</td><td>9.339<sup>***</sup> (df=1; 83)</td><td>4.888<sup>***</sup> (df=2; 82)</td><td>7.702<sup>***</sup> (df=3; 81)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="3" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.007<sup></sup></td><td>0.003<sup></sup></td><td>0.002<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td><td>(0.011)</td><td>(0.011)</td></tr>
# <tr><td style="text-align:left">Prevalence: Workplace Culture</td><td></td><td>0.029<sup></sup></td><td>0.029<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.036)</td><td>(0.036)</td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>0.012<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.086)</td></tr>
# <tr><td style="text-align:left">const</td><td>0.154<sup></sup></td><td>0.046<sup></sup></td><td>-1.185<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.400)</td><td>(0.422)</td><td>(8.840)</td></tr>
#
# <td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>89</td><td>89</td><td>89</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.006</td><td>0.013</td><td>0.013</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>-0.006</td><td>-0.010</td><td>-0.021</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>2.284 (df=87)</td><td>2.288 (df=86)</td><td>2.301 (df=85)</td></tr><tr><td style="text-align: left">F Statistic</td><td>0.500<sup></sup> (df=1; 87)</td><td>0.574<sup></sup> (df=2; 86)</td><td>0.385<sup></sup> (df=3; 85)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="3" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# <table style="text-align:center"><tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="3"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.024<sup></sup></td><td>0.009<sup></sup></td><td>0.010<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.017)</td><td>(0.024)</td><td>(0.024)</td></tr>
# <tr><td style="text-align:left">Prevalence: Remote Work</td><td></td><td>0.036<sup></sup></td><td>0.028<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.042)</td><td>(0.044)</td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>0.112<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.179)</td></tr>
# <tr><td style="text-align:left">const</td><td>-0.873<sup></sup></td><td>-0.999<sup></sup></td><td>-12.474<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.694)</td><td>(0.710)</td><td>(18.270)</td></tr>
#
# <td colspan="4" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>75</td><td>75</td><td>75</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.027</td><td>0.037</td><td>0.043</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.014</td><td>0.011</td><td>0.002</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>3.618 (df=73)</td><td>3.624 (df=72)</td><td>3.639 (df=71)</td></tr><tr><td style="text-align: left">F Statistic</td><td>2.033<sup></sup> (df=1; 73)</td><td>1.396<sup></sup> (df=2; 72)</td><td>1.055<sup></sup> (df=3; 71)</td></tr>
# <tr><td colspan="4" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="3" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %%
import numpy as np

# %% [markdown]
# ## % Change Model (4)

# %%
import statsmodels.api as sm
for benefit in benefits4:
    benefit_df = df_dict[benefit]
    # drop nas in AI Coefficient
    benefit_df = benefit_df.replace([np.inf, -np.inf], np.nan)  # Replace inf with NaN

    benefit_df = benefit_df.dropna(subset=['AI Coefficient', 'AI Demand % Change'])
    
    # Define the dependent and independent variables
    # X is AI ROLE % and Percent_with_{benefit}
    label = benefits_labels_map[benefit]
    # benefit_df.rename(columns={f'{benefit}_prevalence}': f'Prevalence: {label}', inplace=True)
    X = benefit_df['AI Demand % Change']
    print(len(X))
    y = benefit_df['AI Coefficient']
    print(len(y))

    # Add a constant to the independent variable
    X = sm.add_constant(X)

    # Fit the OLS model
    model = sm.OLS(y, X).fit()
    print(benefit)
    benefit_models[benefit].append(model)
    # Print the summary of the regression
    print(model.summary())
# Out:
# 72
# 72
# EDU_ASSISTANCE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.1287
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.721
# Time:                        17:05:10   Log-Likelihood:                -242.53
# No. Observations:                  72   AIC:                             489.1
# Df Residuals:                      70   BIC:                             493.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -2.0200      0.941     -2.147      0.035      -3.897      -0.144
# AI Demand % Change    -0.0072      0.020     -0.359      0.721      -0.047       0.033
# ==============================================================================
# Omnibus:                      105.378   Durbin-Watson:                   1.641
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2083.893
# Skew:                          -4.662   Prob(JB):                         0.00
# Kurtosis:                      27.651   Cond. No.                         52.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 73
# 73
# PAID_LEAVE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.1731
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.679
# Time:                        17:05:10   Log-Likelihood:                -36.600
# No. Observations:                  73   AIC:                             77.20
# Df Residuals:                      71   BIC:                             81.78
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.4708      0.053     -8.886      0.000      -0.576      -0.365
# AI Demand % Change    -0.0005      0.001     -0.416      0.679      -0.003       0.002
# ==============================================================================
# Omnibus:                       41.113   Durbin-Watson:                   1.606
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.064
# Skew:                          -1.848   Prob(JB):                     4.63e-25
# Kurtosis:                       7.815   Cond. No.                         52.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 73
# 73
# HEALTH_WELLBEING
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.045
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     3.367
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):             0.0707
# Time:                        17:05:10   Log-Likelihood:                -141.11
# No. Observations:                  73   AIC:                             286.2
# Df Residuals:                      71   BIC:                             290.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.3284      0.221     -1.487      0.141      -0.769       0.112
# AI Demand % Change     0.0087      0.005      1.835      0.071      -0.001       0.018
# ==============================================================================
# Omnibus:                      142.870   Durbin-Watson:                   2.066
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             9233.744
# Skew:                          -6.968   Prob(JB):                         0.00
# Kurtosis:                      56.306   Cond. No.                         52.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 71
# 71
# PARENTAL_LEAVE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.2064
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.651
# Time:                        17:05:10   Log-Likelihood:                -216.43
# No. Observations:                  71   AIC:                             436.9
# Df Residuals:                      69   BIC:                             441.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -1.6528      0.685     -2.414      0.018      -3.019      -0.287
# AI Demand % Change     0.0066      0.014      0.454      0.651      -0.022       0.035
# ==============================================================================
# Omnibus:                       60.579   Durbin-Watson:                   1.939
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              231.721
# Skew:                          -2.826   Prob(JB):                     4.81e-51
# Kurtosis:                       9.810   Cond. No.                         52.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 74
# 74
# CULTURE
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                   0.05112
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.822
# Time:                        17:05:10   Log-Likelihood:                -172.22
# No. Observations:                  74   AIC:                             348.4
# Df Residuals:                      72   BIC:                             353.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                  0.3307      0.326      1.015      0.313      -0.319       0.980
# AI Demand % Change     0.0016      0.007      0.226      0.822      -0.012       0.016
# ==============================================================================
# Omnibus:                      156.464   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13579.391
# Skew:                          -8.004   Prob(JB):                         0.00
# Kurtosis:                      67.404   Cond. No.                         51.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 74
# 74
# wfh_wham
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         AI Coefficient   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.1030
# Date:                Tue, 22 Oct 2024   Prob (F-statistic):              0.749
# Time:                        17:05:10   Log-Likelihood:                -200.60
# No. Observations:                  74   AIC:                             405.2
# Df Residuals:                      72   BIC:                             409.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 -0.0048      0.478     -0.010      0.992      -0.958       0.948
# AI Demand % Change    -0.0033      0.010     -0.321      0.749      -0.024       0.017
# ==============================================================================
# Omnibus:                      107.344   Durbin-Watson:                   2.210
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1867.621
# Skew:                          -4.778   Prob(JB):                         0.00
# Kurtosis:                      25.680   Cond. No.                         51.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Display Models

# %%
for benefit in benefits4:
    stargazer = Stargazer(benefit_models[benefit])
    stargazer.title(f'Coefficients for {benefits_labels_map[benefit]}')
    display(HTML(stargazer.render_html()))
    # export to latex
    with open(f'../exports/occ_year_coeff_{benefit}.tex', 'w') as f:
        f.write(stargazer.render_latex())
# Out:
# Coefficients for Tuition Assistance<br><table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.071<sup>**</sup></td><td>0.063<sup>**</sup></td><td>0.069<sup>**</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.028)</td><td>(0.028)</td><td>(0.028)</td><td></td></tr>
# <tr><td style="text-align:left">AI Demand % Change</td><td></td><td></td><td></td><td>-0.007<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.020)</td></tr>
# <tr><td style="text-align:left">Prevalence: Tuition Assistance</td><td></td><td>0.253<sup></sup></td><td>0.229<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.164)</td><td>(0.164)</td><td></td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>-0.326<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.250)</td><td></td></tr>
# <tr><td style="text-align:left">const</td><td>-4.443<sup>***</sup></td><td>-5.912<sup>***</sup></td><td>27.648<sup></sup></td><td>-2.020<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(1.167)</td><td>(1.499)</td><td>(25.802)</td><td>(0.941)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>87</td><td>87</td><td>87</td><td>72</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.070</td><td>0.095</td><td>0.113</td><td>0.002</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.059</td><td>0.074</td><td>0.081</td><td>-0.012</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>6.504 (df=85)</td><td>6.452 (df=84)</td><td>6.426 (df=83)</td><td>7.125 (df=70)</td></tr><tr><td style="text-align: left">F Statistic</td><td>6.366<sup>**</sup> (df=1; 85)</td><td>4.423<sup>**</sup> (df=2; 84)</td><td>3.539<sup>**</sup> (df=3; 83)</td><td>0.129<sup></sup> (df=1; 70)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# Coefficients for Paid Leave<br><table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.007<sup>***</sup></td><td>0.007<sup>***</sup></td><td>0.007<sup>***</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.002)</td><td>(0.002)</td><td>(0.002)</td><td></td></tr>
# <tr><td style="text-align:left">AI Demand % Change</td><td></td><td></td><td></td><td>-0.000<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.001)</td></tr>
# <tr><td style="text-align:left">Prevalence: Paid Leave</td><td></td><td>-0.003<sup></sup></td><td>-0.003<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.003)</td><td>(0.003)</td><td></td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>0.003<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.014)</td><td></td></tr>
# <tr><td style="text-align:left">const</td><td>-0.687<sup>***</sup></td><td>-0.588<sup>***</sup></td><td>-0.854<sup></sup></td><td>-0.471<sup>***</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.066)</td><td>(0.120)</td><td>(1.449)</td><td>(0.053)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>88</td><td>88</td><td>88</td><td>73</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.186</td><td>0.196</td><td>0.196</td><td>0.002</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.177</td><td>0.177</td><td>0.167</td><td>-0.012</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>0.373 (df=86)</td><td>0.373 (df=85)</td><td>0.375 (df=84)</td><td>0.405 (df=71)</td></tr><tr><td style="text-align: left">F Statistic</td><td>19.691<sup>***</sup> (df=1; 86)</td><td>10.330<sup>***</sup> (df=2; 85)</td><td>6.819<sup>***</sup> (df=3; 84)</td><td>0.173<sup></sup> (df=1; 71)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# Coefficients for Health and Wellbeing<br><table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.012<sup></sup></td><td>0.011<sup></sup></td><td>0.007<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.008)</td><td>(0.008)</td><td>(0.008)</td><td></td></tr>
# <tr><td style="text-align:left">AI Demand % Change</td><td></td><td></td><td></td><td>0.009<sup>*</sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.005)</td></tr>
# <tr><td style="text-align:left">Prevalence: Health and Wellbeing</td><td></td><td>0.012<sup></sup></td><td>0.026<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.058)</td><td>(0.055)</td><td></td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>0.207<sup>***</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.067)</td><td></td></tr>
# <tr><td style="text-align:left">const</td><td>-0.633<sup>*</sup></td><td>-0.674<sup>*</sup></td><td>-21.945<sup>***</sup></td><td>-0.328<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.335)</td><td>(0.389)</td><td>(6.918)</td><td>(0.221)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>87</td><td>87</td><td>87</td><td>73</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.025</td><td>0.025</td><td>0.125</td><td>0.045</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.013</td><td>0.002</td><td>0.093</td><td>0.032</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>1.867 (df=85)</td><td>1.878 (df=84)</td><td>1.790 (df=83)</td><td>1.695 (df=71)</td></tr><tr><td style="text-align: left">F Statistic</td><td>2.148<sup></sup> (df=1; 85)</td><td>1.084<sup></sup> (df=2; 84)</td><td>3.957<sup>**</sup> (df=3; 83)</td><td>3.367<sup>*</sup> (df=1; 71)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# Coefficients for Parental Leave<br><table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.062<sup>***</sup></td><td>0.056<sup>**</sup></td><td>0.065<sup>***</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.020)</td><td>(0.022)</td><td>(0.021)</td><td></td></tr>
# <tr><td style="text-align:left">AI Demand % Change</td><td></td><td></td><td></td><td>0.007<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.014)</td></tr>
# <tr><td style="text-align:left">Prevalence: Parental Leave</td><td></td><td>0.093<sup></sup></td><td>0.114<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.132)</td><td>(0.124)</td><td></td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>-0.584<sup>***</sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.169)</td><td></td></tr>
# <tr><td style="text-align:left">const</td><td>-3.439<sup>***</sup></td><td>-3.609<sup>***</sup></td><td>56.176<sup>***</sup></td><td>-1.653<sup>**</sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.854)</td><td>(0.890)</td><td>(17.265)</td><td>(0.685)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>85</td><td>85</td><td>85</td><td>71</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.101</td><td>0.107</td><td>0.222</td><td>0.003</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.090</td><td>0.085</td><td>0.193</td><td>-0.011</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>4.723 (df=83)</td><td>4.738 (df=82)</td><td>4.448 (df=81)</td><td>5.174 (df=69)</td></tr><tr><td style="text-align: left">F Statistic</td><td>9.339<sup>***</sup> (df=1; 83)</td><td>4.888<sup>***</sup> (df=2; 82)</td><td>7.702<sup>***</sup> (df=3; 81)</td><td>0.206<sup></sup> (df=1; 69)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# Coefficients for Workplace Culture<br><table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.007<sup></sup></td><td>0.003<sup></sup></td><td>0.002<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.010)</td><td>(0.011)</td><td>(0.011)</td><td></td></tr>
# <tr><td style="text-align:left">AI Demand % Change</td><td></td><td></td><td></td><td>0.002<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.007)</td></tr>
# <tr><td style="text-align:left">Prevalence: Workplace Culture</td><td></td><td>0.029<sup></sup></td><td>0.029<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.036)</td><td>(0.036)</td><td></td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>0.012<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.086)</td><td></td></tr>
# <tr><td style="text-align:left">const</td><td>0.154<sup></sup></td><td>0.046<sup></sup></td><td>-1.185<sup></sup></td><td>0.331<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.400)</td><td>(0.422)</td><td>(8.840)</td><td>(0.326)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>89</td><td>89</td><td>89</td><td>74</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.006</td><td>0.013</td><td>0.013</td><td>0.001</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>-0.006</td><td>-0.010</td><td>-0.021</td><td>-0.013</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>2.284 (df=87)</td><td>2.288 (df=86)</td><td>2.301 (df=85)</td><td>2.514 (df=72)</td></tr><tr><td style="text-align: left">F Statistic</td><td>0.500<sup></sup> (df=1; 87)</td><td>0.574<sup></sup> (df=2; 86)</td><td>0.385<sup></sup> (df=3; 85)</td><td>0.051<sup></sup> (df=1; 72)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>
# Coefficients for Remote Work<br><table style="text-align:center"><tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align:left"></td><td colspan="4"><em>Dependent variable: AI Coefficient</em></td></tr><tr><td style="text-align:left"></td><tr><td style="text-align:left"></td><td>(1)</td><td>(2)</td><td>(3)</td><td>(4)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr>
#
# <tr><td style="text-align:left">AI Demand</td><td>0.024<sup></sup></td><td>0.009<sup></sup></td><td>0.010<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td>(0.017)</td><td>(0.024)</td><td>(0.024)</td><td></td></tr>
# <tr><td style="text-align:left">AI Demand % Change</td><td></td><td></td><td></td><td>-0.003<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td></td><td>(0.010)</td></tr>
# <tr><td style="text-align:left">Prevalence: Remote Work</td><td></td><td>0.036<sup></sup></td><td>0.028<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td>(0.042)</td><td>(0.044)</td><td></td></tr>
# <tr><td style="text-align:left">Salary (Log) Premium</td><td></td><td></td><td>0.112<sup></sup></td><td></td></tr>
# <tr><td style="text-align:left"></td><td></td><td></td><td>(0.179)</td><td></td></tr>
# <tr><td style="text-align:left">const</td><td>-0.873<sup></sup></td><td>-0.999<sup></sup></td><td>-12.474<sup></sup></td><td>-0.005<sup></sup></td></tr>
# <tr><td style="text-align:left"></td><td>(0.694)</td><td>(0.710)</td><td>(18.270)</td><td>(0.478)</td></tr>
#
# <td colspan="5" style="border-bottom: 1px solid black"></td></tr>
# <tr><td style="text-align: left">Observations</td><td>75</td><td>75</td><td>75</td><td>74</td></tr><tr><td style="text-align: left">R<sup>2</sup></td><td>0.027</td><td>0.037</td><td>0.043</td><td>0.001</td></tr><tr><td style="text-align: left">Adjusted R<sup>2</sup></td><td>0.014</td><td>0.011</td><td>0.002</td><td>-0.012</td></tr><tr><td style="text-align: left">Residual Std. Error</td><td>3.618 (df=73)</td><td>3.624 (df=72)</td><td>3.639 (df=71)</td><td>3.690 (df=72)</td></tr><tr><td style="text-align: left">F Statistic</td><td>2.033<sup></sup> (df=1; 73)</td><td>1.396<sup></sup> (df=2; 72)</td><td>1.055<sup></sup> (df=3; 71)</td><td>0.103<sup></sup> (df=1; 72)</td></tr>
# <tr><td colspan="5" style="border-bottom: 1px solid black"></td></tr><tr><td style="text-align: left">Note:</td><td colspan="4" style="text-align: right"><sup>*</sup>p&lt;0.1; <sup>**</sup>p&lt;0.05; <sup>***</sup>p&lt;0.01</td></tr></table>

# %% [markdown]
# # Testing Assumptions

# %% [markdown]
# ## Linearity of Relationships

# %%
import matplotlib.pyplot as plt

for benefit in benefits4:
    model = benefit_models[benefit][0]  # Adjust to the model you want to test
    plt.scatter(model.fittedvalues, model.resid)
    plt.axhline(y=0, color='r', linestyle='--')
    plt.title(f'Residual Plot for {benefit}')
    plt.xlabel('Fitted Values')
    plt.ylabel('Residuals')
    plt.show()

# %% [markdown]
# ## Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

for benefit in benefits4:
    benefit_df = df_dict[benefit]
    
    # Select the independent variables for VIF calculation
    X = benefit_df[['AI Demand % Change', f'Prevalence: {benefits_labels_map[benefit]}', 'Salary (Log) Premium']]
    
    # Replace inf/-inf with NaN
    X = X.replace([np.inf, -np.inf], np.nan)
    
    # Drop rows with NaN values in any of the selected columns
    X = X.dropna()
    
    # Add a constant to the independent variables
    X = sm.add_constant(X)
    
    # Check if there is sufficient data for VIF calculation after dropping NaNs
    if X.shape[0] > 0:
        # Calculate VIF for each variable
        vif_data = pd.DataFrame()
        vif_data["feature"] = X.columns
        vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
        print(f'VIF for {benefit}:')
        print(vif_data)
    else:
        print(f"Insufficient data for VIF calculation in {benefit} after cleaning.")
# Out:
# VIF for EDU_ASSISTANCE:
#                           feature          VIF
# 0                           const  1796.927701
# 1              AI Demand % Change     1.048427
# 2  Prevalence: Tuition Assistance     1.009136
# 3            Salary (Log) Premium     1.057524
# VIF for PAID_LEAVE:
#                   feature          VIF
# 0                   const  1778.011417
# 1      AI Demand % Change     1.226820
# 2  Prevalence: Paid Leave     1.175110
# 3    Salary (Log) Premium     1.048524
# VIF for HEALTH_WELLBEING:
#                             feature          VIF
# 0                             const  1766.167806
# 1                AI Demand % Change     1.048755
# 2  Prevalence: Health and Wellbeing     1.000789
# 3              Salary (Log) Premium     1.048065
# VIF for PARENTAL_LEAVE:
#                       feature          VIF
# 0                       const  1770.248838
# 1          AI Demand % Change     1.054837
# 2  Prevalence: Parental Leave     1.018584
# 3        Salary (Log) Premium     1.056388
# VIF for CULTURE:
#                          feature          VIF
# 0                          const  1763.596348
# 1             AI Demand % Change     1.048005
# 2  Prevalence: Workplace Culture     1.002335
# 3           Salary (Log) Premium     1.050387
# VIF for wfh_wham:
#                    feature          VIF
# 0                    const  1961.672892
# 1       AI Demand % Change     1.050360
# 2  Prevalence: Remote Work     1.134605
# 3     Salary (Log) Premium     1.188006

# %% [markdown]
# ## Autocorrelation of Errors

# %%
from statsmodels.stats.stattools import durbin_watson

for benefit in benefits4:
    model = benefit_models[benefit][0]  # Use the relevant model
    dw_stat = durbin_watson(model.resid)
    print(f'Durbin-Watson statistic for {benefit}: {dw_stat}')
# Out:
# Durbin-Watson statistic for EDU_ASSISTANCE: 1.720769899269018
# Durbin-Watson statistic for PAID_LEAVE: 1.6603528147929025
# Durbin-Watson statistic for HEALTH_WELLBEING: 1.8363230897918073
# Durbin-Watson statistic for PARENTAL_LEAVE: 1.853273031573097
# Durbin-Watson statistic for CULTURE: 2.0508311680528517
# Durbin-Watson statistic for wfh_wham: 2.2198850999288364

# %% [markdown]
# ## Normality of Residuals

# %%
import scipy.stats as stats

for benefit in benefits4:
    model = benefit_models[benefit][0]  # Use the relevant model
    
    # QQ-plot
    stats.probplot(model.resid, dist="norm", plot=plt)
    plt.title(f'QQ-Plot for {benefit}')
    plt.show()
    
    # Jarque-Bera test
    jb_stat, jb_pvalue = stats.jarque_bera(model.resid)
    print(f'Jarque-Bera test for {benefit}: JB Stat={jb_stat}, p-value={jb_pvalue}')
# Out:
# Jarque-Bera test for EDU_ASSISTANCE: JB Stat=2597.4296677796856, p-value=0.0
# Jarque-Bera test for PAID_LEAVE: JB Stat=89.22411360196429, p-value=4.219197984412188e-20
# Jarque-Bera test for HEALTH_WELLBEING: JB Stat=4729.883980325258, p-value=0.0
# Jarque-Bera test for PARENTAL_LEAVE: JB Stat=215.7645565977746, p-value=1.403853663412573e-47
# Jarque-Bera test for CULTURE: JB Stat=22869.424901435246, p-value=0.0
# Jarque-Bera test for wfh_wham: JB Stat=1658.3044360306133, p-value=0.0

# %% [markdown]
# ## Homoscedasticity

# %%
from statsmodels.stats.diagnostic import het_breuschpagan
for benefit in benefits4:
    print(f'Breusch-Pagan test for {benefit}:')
    for i in range(4):
        model = benefit_models[benefit][i]  # Use the relevant model
        test_result = het_breuschpagan(model.resid, model.model.exog)
        print(f'LM Statistic: {test_result[i]}, p-value: {test_result[1]}')
# Out:
# Breusch-Pagan test for EDU_ASSISTANCE:
# LM Statistic: 2.2900873661250465, p-value: 0.1302025938870422
# LM Statistic: 0.09921791221441975, p-value: 0.09921791221441975
# LM Statistic: 1.5260534103730041, p-value: 0.20805408049519963
# LM Statistic: 0.712216189125856, p-value: 0.7074607990076791
# Breusch-Pagan test for PAID_LEAVE:
# LM Statistic: 4.930611925215087, p-value: 0.026384972787951134
# LM Statistic: 0.08411517735863519, p-value: 0.08411517735863519
# LM Statistic: 1.7270561434086118, p-value: 0.16373905868196567
# LM Statistic: 0.8049571305067388, p-value: 0.8016444621672019
# Breusch-Pagan test for HEALTH_WELLBEING:
# LM Statistic: 2.3745470618683022, p-value: 0.12332736333590433
# LM Statistic: 0.3018943424680463, p-value: 0.3018943424680463
# LM Statistic: 4.3791936708257415, p-value: 0.00777361588278299
# LM Statistic: 0.2552828104383728, p-value: 0.24920059248938206
# Breusch-Pagan test for PARENTAL_LEAVE:
# LM Statistic: 7.552226963509781, p-value: 0.005993595811737298
# LM Statistic: 0.017887772263269246, p-value: 0.017887772263269246
# LM Statistic: 2.4335401411506754, p-value: 0.07101922079941231
# LM Statistic: 0.8590303009224561, p-value: 0.8565265799106803
# Breusch-Pagan test for CULTURE:
# LM Statistic: 0.9887259714146279, p-value: 0.3200539576763261
# LM Statistic: 0.45619991358965883, p-value: 0.45619991358965883
# LM Statistic: 0.5343815930691053, p-value: 0.648664981950968
# LM Statistic: 0.7734667280330432, p-value: 0.7697180242416414
# Breusch-Pagan test for wfh_wham:
# LM Statistic: 3.163683204706164, p-value: 0.0752931316721517
# LM Statistic: 0.11935139404303977, p-value: 0.11935139404303977
# LM Statistic: 1.7010040281711112, p-value: 0.16968222689954385
# LM Statistic: 0.6425219680644751, p-value: 0.6370273633241268
