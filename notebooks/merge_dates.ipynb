# %%
import pandas as pd

# %%
data = pd.read_parquet('../data/us_10m_nointernship_ai_skills_benefits.parquet.gzip')

# %%
pd.set_option('display.max_columns', None)

# %%
dates = pd.read_parquet('../data/US_10M_POSTS_DATES.parquet.gzip')

# %%
data = data.merge(dates, on='ID', how = 'left')

# %%
data[data['EXPIRED'].isna()]
# Out:
# Empty DataFrame
# Columns: [ID, CITY_NAME, COUNTY_NAME, STATE_NAME, NAICS_2022_2, NAICS_2022_2_NAME, MIN_EDULEVELS_NAME, EMPLOYMENT_TYPE, EMPLOYMENT_TYPE_NAME, IS_INTERNSHIP, REMOTE_TYPE, REMOTE_TYPE_NAME, SKILLS, SKILLS_NAME, POSTED, LAST_UPDATED_DATE, ONET, ONET_NAME, ONET_2019, ONET_2019_NAME, SOC_2021_2_NAME, SOC_2021_2, MIN_YEARS_EXPERIENCE, COMPANY, COMPANY_NAME, COMPANY_RAW, AI ROLE, wfh_wham_prob, wfh_wham, YEAR, EDU_ASSISTANCE, WLB, PAID_LEAVE, HEALTH_WELLBEING, PARENTAL_LEAVE, CULTURE, EXPERIENCE_BUCKET, SALARY, LOG_SALARY, EXPIRED, DURATION]
# Index: []
#
# [0 rows x 41 columns]

# %%
len(data)
# Out:
# 11581326

# %%
data[data['DURATION'].isna()]
# Out:
#                                                 ID      CITY_NAME  \
# 0         b5e9360ab429758bc6e8e259fcf66234d3163dcf  Brentwood, TN
# 1         eff8c5c87b50735a4684ebc33d41d1b36ff46aa8     Smyrna, TN
# 2         b8b974adf881aa6c934392d71ad46dff810dcb34     Denver, CO
# 4         1513ec98d6d7b3ffda588c9834a9ac2e47f8921b      Plano, TX
# 7         76eda7de4238503b2f9a21af8a51f1b43916c5f9     Gretna, LA
# ...                                            ...            ...
# 11581321  623fbd0258922f47db0dc616a5e2754f91a65685    Houston, TX
# 11581322  b6e4667b5eefe314c009c1809404834d37a80ce0    Atlanta, GA
# 11581323  0fbd0a7227f24b8e665649acb79f3c1772b7cf46  Hauppauge, NY
# 11581324  df22cd59c119ecea024e4445f37a03f0b1540345   Lynbrook, NY
# 11581325  060d09035f9dd9ba5b1b08a236573d8cedf17c01      Fargo, ND
#
#              COUNTY_NAME    STATE_NAME  NAICS_2022_2  \
# 0         Williamson, TN     Tennessee            62
# 1         Rutherford, TN     Tennessee            72
# 2             Denver, CO      Colorado            52
# 4             Collin, TX         Texas            31
# 7          Jefferson, LA     Louisiana            72
# ...                  ...           ...           ...
# 11581321      Harris, TX         Texas            62
# 11581322      Fulton, GA       Georgia            31
# 11581323     Suffolk, NY      New York            56
# 11581324      Nassau, NY      New York            54
# 11581325        Cass, ND  North Dakota            62
#
#                                           NAICS_2022_2_NAME  \
# 0                         Health Care and Social Assistance
# 1                           Accommodation and Food Services
# 2                                     Finance and Insurance
# 4                                             Manufacturing
# 7                           Accommodation and Food Services
# ...                                                     ...
# 11581321                  Health Care and Social Assistance
# 11581322                                      Manufacturing
# 11581323  Administrative and Support and Waste Managemen...
# 11581324   Professional, Scientific, and Technical Services
# 11581325                  Health Care and Social Assistance
#
#            MIN_EDULEVELS_NAME  EMPLOYMENT_TYPE    EMPLOYMENT_TYPE_NAME  \
# 0             Master's degree                1  Full-time (> 32 hours)
# 1          High school or GED                1  Full-time (> 32 hours)
# 2           Bachelor's degree                1  Full-time (> 32 hours)
# 4           Bachelor's degree                1  Full-time (> 32 hours)
# 7          High school or GED                1  Full-time (> 32 hours)
# ...                       ...              ...                     ...
# 11581321   High school or GED                1  Full-time (> 32 hours)
# 11581322    Bachelor's degree                1  Full-time (> 32 hours)
# 11581323  No Education Listed                1  Full-time (> 32 hours)
# 11581324    Bachelor's degree                1  Full-time (> 32 hours)
# 11581325   High school or GED                2  Part-time (≤ 32 hours)
#
#           IS_INTERNSHIP  ...    WLB PAID_LEAVE HEALTH_WELLBEING  \
# 0                 False  ...   True       True             True
# 1                 False  ...  False      False            False
# 2                 False  ...  False      False            False
# 4                 False  ...  False      False            False
# 7                 False  ...  False      False            False
# ...                 ...  ...    ...        ...              ...
# 11581321          False  ...   True       True            False
# 11581322          False  ...  False      False            False
# 11581323          False  ...  False      False            False
# 11581324          False  ...  False      False            False
# 11581325          False  ...   True       True            False
#
#          PARENTAL_LEAVE CULTURE EXPERIENCE_BUCKET   SALARY LOG_SALARY  \
# 0                 False   False        6-10 years      NaN        NaN
# 1                 False   False       None Listed      NaN        NaN
# 2                 False   False         3-5 years      NaN        NaN
# 4                 False   False         3-5 years      NaN        NaN
# 7                 False   False       None Listed      NaN        NaN
# ...                 ...     ...               ...      ...        ...
# 11581321          False   False         1-2 years      NaN        NaN
# 11581322          False    True       None Listed      NaN        NaN
# 11581323          False   False         1-2 years  43680.0  10.684646
# 11581324          False   False       None Listed      NaN        NaN
# 11581325          False   False       None Listed      NaN        NaN
#
#              EXPIRED DURATION
# 0         2020-02-05      NaN
# 1         2020-03-07      NaN
# 2         2020-02-04      NaN
# 4         2020-02-27      NaN
# 7         2020-04-02      NaN
# ...              ...      ...
# 11581321  2021-05-07      NaN
# 11581322  2021-03-15      NaN
# 11581323  2021-03-10      NaN
# 11581324  2021-03-16      NaN
# 11581325  2021-04-04      NaN
#
# [8020806 rows x 41 columns]

# %%
# get EXPIRED data type
data['EXPIRED'] = pd.to_datetime(data['EXPIRED'])

# %%
data['POSTED'] = pd.to_datetime(data['POSTED'])

# %%
data['DURATION_CALC'] = data['EXPIRED'] - data['POSTED']

# %%
data['DURATION_CALC']
# Out:
# 0           62 days
# 1           93 days
# 2           61 days
# 3           59 days
# 4           84 days
#              ...
# 11581321   119 days
# 11581322    66 days
# 11581323    61 days
# 11581324    67 days
# 11581325    86 days
# Name: DURATION_CALC, Length: 11581326, dtype: timedelta64[ns]

# %%
data['DURATION_CALC'].describe()
# Out:
# count                      11581326
# mean     59 days 08:43:06.190078755
# std      26 days 16:04:52.115791118
# min                 0 days 00:00:00
# 25%                43 days 00:00:00
# 50%                61 days 00:00:00
# 75%                69 days 00:00:00
# max               120 days 00:00:00
# Name: DURATION_CALC, dtype: object

# %%
data['DURATION_CALC'] = pd.to_timedelta(data['DURATION_CALC']).dt.total_seconds() / (24 * 3600)

# %%
# histogram with title and x labels
import matplotlib.pyplot as plt
plt.title('Duration of job postings')
plt.xlabel('Duration in days')
plt.ylabel('Number of job postings')
data['DURATION_CALC'].hist(grid = False)
# Out:
# <Axes: title={'center': 'Duration of job postings'}, xlabel='Duration in days', ylabel='Number of job postings'>

# %%
data.to_parquet('../data/us_10m_nointernship_ai_skills_benefits.parquet.gzip', compression='gzip')

# %%
data[['POSTED','EXPIRED','DURATION', 'DURATION_CALC']]
# Out:
#              POSTED    EXPIRED  DURATION  DURATION_CALC
# 0        2019-12-05 2020-02-05       NaN           62.0
# 1        2019-12-05 2020-03-07       NaN           93.0
# 2        2019-12-05 2020-02-04       NaN           61.0
# 3        2019-12-05 2020-02-02      59.0           59.0
# 4        2019-12-05 2020-02-27       NaN           84.0
# ...             ...        ...       ...            ...
# 11581321 2021-01-08 2021-05-07       NaN          119.0
# 11581322 2021-01-08 2021-03-15       NaN           66.0
# 11581323 2021-01-08 2021-03-10       NaN           61.0
# 11581324 2021-01-08 2021-03-16       NaN           67.0
# 11581325 2021-01-08 2021-04-04       NaN           86.0
#
# [11581326 rows x 4 columns]

# %%
data.groupby('YEAR')['DURATION_CALC'].mean()
# Out:
# YEAR
# 2018    62.656125
# 2019    60.170249
# 2020    61.011658
# 2021    65.964202
# 2022    57.196716
# 2023    49.703581
# Name: DURATION_CALC, dtype: float64

# %%
# plot the average duration of job postings per year per AI role
data.groupby(['YEAR', 'AI ROLE'])['DURATION_CALC'].mean().unstack().plot()
# Out:
# <Axes: xlabel='YEAR'>
